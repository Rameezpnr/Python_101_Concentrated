# %% [markdown]
# ## MatplotLib Tutorial
#
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general

# %%
import matplotlib.pyplot as plt

#below helps for direct execution (plt.show is not required)
# %matplotlib inline

# %%
import numpy as np

# %%
## Simple Examples


x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##plotting using matplotlib 

##plt scatter

plt.scatter(x,y,c='g')
#here g means green
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')

#for saving the plot as png
plt.savefig('Test.png')

# %%
y=x*x

# %%
## plt plot

plt.plot(x,y,'r*',linestyle='dashed',linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
## Creating Subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,4)
plt.plot(x,y,'bo')
plt.subplot(2,2,3)
plt.plot(x,y,'go')


# means to use 2x2 space and use specific position
#(No. of row, No. of col, position )

# %%
x = np.arange(1,111) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
# Area of circle
r = np.arange(1,10)
np.pi
Area = np.pi*r**2
plt.plot(r,Area)

# %%
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 4 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 

# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
## Bar plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y, color = 'r') 
plt.bar(x2, y2, color = 'g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %% [markdown]
# ## Histograms

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a, bins=7) 
#default no. of bins in histogram is 10
plt.title("histogram") 
plt.show()

# %% [markdown]
# ## Box Plot using Matplotlib

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
#3 list got created, each scale between 1, 2 and 3


# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %%
data
# Out:
# [array([-0.49791401, -0.14600142, -0.26280803, -0.41331187,  1.00316617,
#         -2.30114784,  0.32586905,  2.00213997,  0.82733771,  1.26981207,
#          0.49907008,  0.85355779,  0.22560397, -1.33899179, -1.12062972,
#         -1.35193374,  1.17145749, -0.60700945, -0.16728605,  1.28715294,
#          1.54122723,  1.14751578, -0.36477874,  2.8516253 , -0.51721877,
#          0.14177368, -0.01435952,  1.50165622, -0.84551748,  0.33589918,
#          0.73229742, -0.39722409,  0.21177526, -1.85747098,  0.3973298 ,
#         -0.56204034,  0.00740872,  0.86590699, -1.08944676, -1.04984688,
#         -0.94810905,  1.31662018,  0.21529883,  0.9059598 , -0.51388848,
#          2.38427301,  1.53988258, -0.39157039,  0.01361547,  0.27551258,
#          0.09038117, -0.31354579,  0.18789289,  1.54698145,  1.685735  ,
#         -0.22076304,  1.18331765,  1.38277224, -0.49257235,  0.77767087,
#         -0.43827505, -0.32326422,  0.4913805 , -0.01188962, -0.65400746,
# ...

# %% [markdown]
# ## Pie Chart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.4, 0, 0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True)

plt.axis('equal')
plt.show()
